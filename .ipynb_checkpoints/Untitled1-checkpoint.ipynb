# %%
import pandas as pd
import numpy as np

# %%
from sklearn.ensemble import IsolationForest
from sklearn.cluster import DBSCAN, KMeans

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
dfep = pd.read_csv('E:/KrishM/PythonPrjs/FraudDetection/moneylaunder/ellipticex/elliptic_bitcoin_dataset/elliptic_txs_features.csv')

# %%
dfep
# Out:
#                 0   1         2         3         4          5         6  \
# 0       230425980   1 -0.171469 -0.184668 -1.201369  -0.121970 -0.043875
# 1         5530458   1 -0.171484 -0.184668 -1.201369  -0.121970 -0.043875
# 2       232022460   1 -0.172107 -0.184668 -1.201369  -0.121970 -0.043875
# 3       232438397   1  0.163054  1.963790 -0.646376  12.409294 -0.063725
# 4       230460314   1  1.011523 -0.081127 -1.201369   1.153668  0.333276
# ...           ...  ..       ...       ...       ...        ...       ...
# 203764  173077460  49 -0.145771 -0.163752  0.463609  -0.121970 -0.043875
# 203765  158577750  49 -0.165920 -0.123607  1.018602  -0.121970 -0.043875
# 203766  158375402  49 -0.172014 -0.078182  1.018602   0.028105 -0.043875
# 203767  158654197  49 -0.172842 -0.176622  1.018602  -0.121970 -0.043875
# 203768  157597225  49 -0.012037 -0.132276  0.463609  -0.121970 -0.043875
#
#                7          8         9  ...       157       158       159  \
# ...

# %%
mddb = DBSCAN(eps=0.5, min_samples=20)

# %%
dfep['0'] = MinMaxScaler().fit_transform(dfep[['0']])

# %%
dfep
# Out:
#                0   1         2         3         4          5         6  \
# 0       0.571429   1 -0.171469 -0.184668 -1.201369  -0.121970 -0.043875
# 1       0.013712   1 -0.171484 -0.184668 -1.201369  -0.121970 -0.043875
# 2       0.575388   1 -0.172107 -0.184668 -1.201369  -0.121970 -0.043875
# 3       0.576419   1  0.163054  1.963790 -0.646376  12.409294 -0.063725
# 4       0.571514   1  1.011523 -0.081127 -1.201369   1.153668  0.333276
# ...          ...  ..       ...       ...       ...        ...       ...
# 203764  0.429211  49 -0.145771 -0.163752  0.463609  -0.121970 -0.043875
# 203765  0.393253  49 -0.165920 -0.123607  1.018602  -0.121970 -0.043875
# 203766  0.392751  49 -0.172014 -0.078182  1.018602   0.028105 -0.043875
# 203767  0.393442  49 -0.172842 -0.176622  1.018602  -0.121970 -0.043875
# 203768  0.390821  49 -0.012037 -0.132276  0.463609  -0.121970 -0.043875
#
#                7          8         9  ...       157       158       159  \
# ...

# %%
dfep['1'].value_counts()
# Out:
# 1     7880
# 42    7140
# 5     6803
# 10    6727
# 3     6621
# 36    6393
# 7     6048
# 22    5894
# 4     5693
# 45    5598
# 35    5507
# 41    5342
# 47    5121
# 43    5063
# 9     4996
# 44    4975
# 24    4592
# 2     4544
# 13    4528
# 32    4525
# 40    4481
# 8     4457
# 6     4328
# 11    4296
# 20    4291
# 29    4275
# 23    4165
# 15    3639
# 21    3537
# 46    3519
# 19    3506
# 17    3385
# 37    3306
# 33    3151
# 16    2975
# 48    2954
# 38    2891
# 31    2816
# 39    2760
# 26    2523
# 34    2486
# 30    2483
# 49    2454
# 25    2314
# 12    2047
# 14    2022
# 18    1976
# 28    1653
# 27    1089
# Name: 1, dtype: int64

# %%
dfep['1'] = MinMaxScaler().fit_transform(dfep[['1']])

# %%
dfep
# Out:
#                0    1         2         3         4          5         6  \
# 0       0.571429  0.0 -0.171469 -0.184668 -1.201369  -0.121970 -0.043875
# 1       0.013712  0.0 -0.171484 -0.184668 -1.201369  -0.121970 -0.043875
# 2       0.575388  0.0 -0.172107 -0.184668 -1.201369  -0.121970 -0.043875
# 3       0.576419  0.0  0.163054  1.963790 -0.646376  12.409294 -0.063725
# 4       0.571514  0.0  1.011523 -0.081127 -1.201369   1.153668  0.333276
# ...          ...  ...       ...       ...       ...        ...       ...
# 203764  0.429211  1.0 -0.145771 -0.163752  0.463609  -0.121970 -0.043875
# 203765  0.393253  1.0 -0.165920 -0.123607  1.018602  -0.121970 -0.043875
# 203766  0.392751  1.0 -0.172014 -0.078182  1.018602   0.028105 -0.043875
# 203767  0.393442  1.0 -0.172842 -0.176622  1.018602  -0.121970 -0.043875
# 203768  0.390821  1.0 -0.012037 -0.132276  0.463609  -0.121970 -0.043875
#
#                7          8         9  ...       157       158       159  \
# ...
