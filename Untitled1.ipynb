# %%
import pandas as pd
import numpy as np

# %%
from sklearn.ensemble import IsolationForest
from sklearn.cluster import DBSCAN, KMeans

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
dfep = pd.read_csv('E:/KrishM/PythonPrjs/FraudDetection/moneylaunder/ellipticex/elliptic_bitcoin_dataset/elliptic_txs_features.csv')

# %%
dfep
# Out:
#                 0   1         2         3         4          5         6  \
# 0       230425980   1 -0.171469 -0.184668 -1.201369  -0.121970 -0.043875
# 1         5530458   1 -0.171484 -0.184668 -1.201369  -0.121970 -0.043875
# 2       232022460   1 -0.172107 -0.184668 -1.201369  -0.121970 -0.043875
# 3       232438397   1  0.163054  1.963790 -0.646376  12.409294 -0.063725
# 4       230460314   1  1.011523 -0.081127 -1.201369   1.153668  0.333276
# ...           ...  ..       ...       ...       ...        ...       ...
# 203764  173077460  49 -0.145771 -0.163752  0.463609  -0.121970 -0.043875
# 203765  158577750  49 -0.165920 -0.123607  1.018602  -0.121970 -0.043875
# 203766  158375402  49 -0.172014 -0.078182  1.018602   0.028105 -0.043875
# 203767  158654197  49 -0.172842 -0.176622  1.018602  -0.121970 -0.043875
# 203768  157597225  49 -0.012037 -0.132276  0.463609  -0.121970 -0.043875
#
#                7          8         9  ...       157       158       159  \
# ...

# %%
mddb = DBSCAN(eps=0.5, min_samples=100)

# %%
dfep['0'] = MinMaxScaler(feature_range=(0, 1)).fit_transform(dfep[['0']])

# %%
dfep['1'] = MinMaxScaler(feature_range=(0, 1)).fit_transform(dfep[['1']])

# %%
dfep = dfep.sample(100000)

# %%
dfep
# Out:
#                0         1         2         3         4         5         6  \
# 12253   0.768639  0.020833 -0.171401 -0.184668 -1.201369 -0.046932 -0.043875
# 71207   0.598901  0.291667 -0.172799 -0.081127 -1.201369  0.103143 -0.043875
# 141498  0.173549  0.708333  0.253515 -0.105718 -0.091383 -0.121970 -0.043875
# 161731  0.031429  0.833333 -0.169112  0.019185  1.018602 -0.121970 -0.043875
# 187337  0.387418  0.916667 -0.171605 -0.123307  1.018602 -0.121970 -0.043875
# ...          ...       ...       ...       ...       ...       ...       ...
# 146614  0.497062  0.729167 -0.172910  0.752370 -0.091383 -0.046932 -0.043875
# 119273  0.406263  0.583333 -0.155105 -0.143252 -0.646376 -0.121970 -0.043875
# 135758  0.714405  0.687500 -0.172899 -0.081852  0.463609 -0.121970 -0.043875
# 77362   0.853831  0.312500  0.065800 -0.081127 -1.201369 -0.121970 -0.043875
# 163447  0.033189  0.833333 -0.166792  0.262367  0.463609  0.028105 -0.043875
#
# ...

# %%
dfep.reset_index(drop=True, inplace=True)

# %%
dfep
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.768639  0.020833 -0.171401 -0.184668 -1.201369 -0.046932 -0.043875
# 1      0.598901  0.291667 -0.172799 -0.081127 -1.201369  0.103143 -0.043875
# 2      0.173549  0.708333  0.253515 -0.105718 -0.091383 -0.121970 -0.043875
# 3      0.031429  0.833333 -0.169112  0.019185  1.018602 -0.121970 -0.043875
# 4      0.387418  0.916667 -0.171605 -0.123307  1.018602 -0.121970 -0.043875
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  0.497062  0.729167 -0.172910  0.752370 -0.091383 -0.046932 -0.043875
# 99996  0.406263  0.583333 -0.155105 -0.143252 -0.646376 -0.121970 -0.043875
# 99997  0.714405  0.687500 -0.172899 -0.081852  0.463609 -0.121970 -0.043875
# 99998  0.853831  0.312500  0.065800 -0.081127 -1.201369 -0.121970 -0.043875
# 99999  0.033189  0.833333 -0.166792  0.262367  0.463609  0.028105 -0.043875
#
# ...

# %%
clstrs = mddb.fit_predict(dfep)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-36-9365930ae8de> in <module>
# ----> 1 clstrs = mddb.fit_predict(dfep)
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_dbscan.py in fit_predict(self, X, y, sample_weight)
#     387             Cluster labels. Noisy samples are given the label -1.
#     388         """
# --> 389         self.fit(X, sample_weight=sample_weight)
#     390         return self.labels_
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_dbscan.py in fit(self, X, y, sample_weight)
#     332         neighbors_model.fit(X)
#     333         # This has worst case O(n^2) memory complexity
# --> 334         neighborhoods = neighbors_model.radius_neighbors(X,
#     335                                                          return_distance=False)
#     336
#
# ...

# %%
dfep['1'].value_counts()
# Out:
# 1     7880
# 42    7140
# 5     6803
# 10    6727
# 3     6621
# 36    6393
# 7     6048
# 22    5894
# 4     5693
# 45    5598
# 35    5507
# 41    5342
# 47    5121
# 43    5063
# 9     4996
# 44    4975
# 24    4592
# 2     4544
# 13    4528
# 32    4525
# 40    4481
# 8     4457
# 6     4328
# 11    4296
# 20    4291
# 29    4275
# 23    4165
# 15    3639
# 21    3537
# 46    3519
# 19    3506
# 17    3385
# 37    3306
# 33    3151
# 16    2975
# 48    2954
# 38    2891
# 31    2816
# 39    2760
# 26    2523
# 34    2486
# 30    2483
# 49    2454
# 25    2314
# 12    2047
# 14    2022
# 18    1976
# 28    1653
# 27    1089
# Name: 1, dtype: int64

# %%
dfep['1'] = MinMaxScaler().fit_transform(dfep[['1']])

# %%
dfep
# Out:
#                0    1         2         3         4          5         6  \
# 0       0.571429  0.0 -0.171469 -0.184668 -1.201369  -0.121970 -0.043875
# 1       0.013712  0.0 -0.171484 -0.184668 -1.201369  -0.121970 -0.043875
# 2       0.575388  0.0 -0.172107 -0.184668 -1.201369  -0.121970 -0.043875
# 3       0.576419  0.0  0.163054  1.963790 -0.646376  12.409294 -0.063725
# 4       0.571514  0.0  1.011523 -0.081127 -1.201369   1.153668  0.333276
# ...          ...  ...       ...       ...       ...        ...       ...
# 203764  0.429211  1.0 -0.145771 -0.163752  0.463609  -0.121970 -0.043875
# 203765  0.393253  1.0 -0.165920 -0.123607  1.018602  -0.121970 -0.043875
# 203766  0.392751  1.0 -0.172014 -0.078182  1.018602   0.028105 -0.043875
# 203767  0.393442  1.0 -0.172842 -0.176622  1.018602  -0.121970 -0.043875
# 203768  0.390821  1.0 -0.012037 -0.132276  0.463609  -0.121970 -0.043875
#
#                7          8         9  ...       157       158       159  \
# ...

# %%
mddb.fit_predict(dfep)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-081fe94cec64> in <module>
# ----> 1 mddb.fit_predict(dfep)
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_dbscan.py in fit_predict(self, X, y, sample_weight)
#     387             Cluster labels. Noisy samples are given the label -1.
#     388         """
# --> 389         self.fit(X, sample_weight=sample_weight)
#     390         return self.labels_
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_dbscan.py in fit(self, X, y, sample_weight)
#     332         neighbors_model.fit(X)
#     333         # This has worst case O(n^2) memory complexity
# --> 334         neighborhoods = neighbors_model.radius_neighbors(X,
#     335                                                          return_distance=False)
#     336
#
# ...
